# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("data3.csv")
df
# Out:
#     cake    price
# 0      1   100.00
# 1      2   150.00
# 2      3   250.00
# 3      4   300.00
# 4      5   400.00
# 5      6   450.00
# 6      7   600.00
# 7      8   800.00
# 8      9  1000.00
# 9     10  1500.00
# 10    12  1431.51

# %%
plt.xlabel("cake")
plt.ylabel("price")
plt.scatter(df.cake,df.price)
plt
# Out:
# <module 'matplotlib.pyplot' from 'c:\\Users\\War_Lock\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
reg = LinearRegression()
reg.fit(df[["cake"]],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[12]])
# Out:
# c:\Users\War_Lock\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1431.51319549])
